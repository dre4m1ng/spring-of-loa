# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\sam\appdata\roaming\python\python310\site-packages (4.6.0.66)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\sam\miniconda3\envs\project\lib\site-packages (from opencv-python) (1.24.2)

# %%
import numpy as np
import cv2
import os

# %% [markdown]
# # Video Class

# %%
class VideoPreprocessor:
    def __init__(self, video_path, save_folder, save_name_prefix, fps=10, save=False, size_type=1, quality=700):
        self.video_path = video_path
        self.save_folder = save_folder
        self.save_name_prefix = str(save_name_prefix)
        self.fps = fps
        self.size_type = size_type
        self.quality = quality
        self.save = save

    def preprocess_video(self, operations):
        # cv2로 영상 파일 읽기
        cap = cv2.VideoCapture(self.video_path)

        # 설정한 FPS에 맞춰 간격을 계산
        frame_interval = round(cap.get(cv2.CAP_PROP_FPS) / self.fps)  # fps = 내가 원하는 output의 fps 10 fps = 60/10 => 1초에 10장이 나오는 6fps으로 나눈것.
        total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
        current_frame = 0

        # 저장 폴더가 없다면 생성
        if not os.path.exists(self.save_folder):
            os.makedirs(self.save_folder)

        while True:
            # 영상에서 프레임을 하나씩 읽어옴
            ret, frame = cap.read()


            # 더 이상 읽을 프레임이 없으면 종료
            if not ret:
                break

            # 설정한 FPS에 맞춰 프레임 저장
            if current_frame % frame_interval == 0:
                try:
                    # 전처리 객체 생성 및 전처리 수행
                    preprocess_obj = preprocess(frame, self.save_folder, f"{self.save_name_prefix}_{current_frame}", save=self.save, size_type=self.size_type, quality=self.quality)    # 여기서 저장여부를 결정

                    processed_frame = preprocess_obj.process_image(operations)

                    # 전처리된 프레임을 다시 영상으로 저장
                    out_path = os.path.join(self.save_folder, f"{self.save_name_prefix}_{current_frame}.jpg")
                    cv2.imwrite(out_path, processed_frame)
                    print(f"{out_path} 저장 완료 ({current_frame}/{total_frames})")

                except Exception as e:
                    print(f"Error processing frame {current_frame}: {e}")

            # 프레임 번호 업데이트
            current_frame += 1

        # 자원 해제
        cap.release()
        print("작업 완료")

# %% [markdown]
# # Preprocess Class

# %%
class preprocess():
    def __init__(self, image_data, save_folder, save_name, save=False, size_type=1, quality=700):
        self.image = cv2.resize(image_data, (1920, 1080))
        self.save_folder = save_folder
        self.save_name = save_name
        self.save = save
        self.size_type = size_type
        self.quality = quality
        self.mask_regions = mask_regions = [
                                            ((0, 0), (888, 25)),  # 상단 상태 표시줄
                                            ((705, 30), (1195, 120)), # 보스 체력, 이름 게이지
                                            ((695, 165), (1110, 175)), # 보스 상태이상
                                            ((0, 1052), (257, 1072)), # 하단 레벨 표시
                                            ((650, 970), (1300, 1070)), # 스킬, 체력 게이지
                                            ((430, 900), (870, 970)), # 버프 표시줄
                                            ((1520, 1030), (1900, 1070)), # 설정창
                                            ((0, 790), (430, 1020)), # 채팅창
                                            ((0, 340), (230, 640)), # 파티창
                                            ((1630, 0), (1920, 300)), # 미니맵
                                            ((1570, 20), (1620, 150)), # 미니맵 옆
                                            ((1630, 410), (1920, 650)), # 퀘스트창
                                            ((80, 50), (180, 95)), # 레이드 이름
                                            ((630, 100), (690, 130)), # 광폭화까지 타이머
                                            ((780, 30), (730, 45)), # 보스
                                        ]
        self.mask = self.create_mask(self.image.shape, self.mask_regions)


    def create_mask(self, image_shape, mask_regions):
        # 마스크 이미지 생성
        mask = np.zeros(image_shape[:2], dtype=np.uint8)

        # 마스크 영역을 흰색으로 채우기
        for region in mask_regions:
            cv2.rectangle(mask, region[0], region[1], 255, -1)
        return mask


    def apply_mask(self, save=False):
        # 마스크 반전
        mask_inv = cv2.bitwise_not(self.mask)

        # 적용
        masked_image = cv2.bitwise_and(self.image, self.image, mask=mask_inv)

        # 최종 결과를 저장
        if self.save:
            cv2.imwrite(os.path.join(self.save_folder, self.save_name + '_mask.jpg'), masked_image)

        self.image = masked_image
        return self.image


    def resize_image(self, image=None, save=False):   # 해상도 조절
        if image is None:
            image = self.image

        if self.size_type == 1:
            # 이미지를 700x700으로 줄임
            image = cv2.resize(image, (self.quality, self.quality))   # 700, 750, 800, 850 1:1 비율
            # 다시 1920x1080으로 확대
            image = cv2.resize(image, (1920, 1080))
        if self.size_type == 2:
            # 이미지를 720x405 줄임
            image = cv2.resize(image, (720, 405))   # 720:405 비율
            # 다시 1920x1080으로 확대
            image = cv2.resize(image, (1024, 576))

        resize_image = image
        # 최종 결과를 저장
        if self.save:
            cv2.imwrite(os.path.join(self.save_folder, self.save_name + '_quality.jpg'), resize_image)

        self.image = resize_image
        return self.image


    def extract_yellow(self, image=None, save=False):   # 이미지 처리
        if image is None:
            image = self.image

        # HSV(Hue, Saturation, Value)로 이미지를 변환합니다.
        hsv_image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

        # 노란색의 HSV 범위를 정의합니다.                               # 남궁맑음
        lower_yellow = np.array([20, 160, 215])  # 노란색의 하한값      # [30, 150, 120]
        upper_yellow = np.array([40, 255, 255])  # 노란색의 상한값      # [90, 255, 255]

        # HSV 이미지에서 노란색 범위에 해당하는 픽셀을 찾습니다.
        yellow_mask = cv2.inRange(hsv_image, lower_yellow, upper_yellow)

        # 노란색을 제외한 나머지 부분을 검은색으로 대체합니다.
        # 새 이미지 생성
        result_image = image.copy()
        result_image[yellow_mask == 0] = [0, 0, 0]

        # 최종 결과물 저장
        if self.save:
            cv2.imwrite(os.path.join(self.save_folder, self.save_name + '_extract_Cri.jpg'), result_image)

        self.image = result_image
        return self.image


    def extract_white(self, image=None, save=False):
        if image is None:
            image = self.image

        # HSV(Hue, Saturation, Value)로 이미지를 변환합니다.
        hsv_image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

        # 하얀색의 HSV 범위를 정의합니다. (하얀색은 채도가 낮고 명도가 높습니다.)
        lower_white = np.array([0, 0, 200])
        upper_white = np.array([180, 25, 255])

        # HSV 이미지에서 하얀색 범위에 해당하는 픽셀을 찾습니다.
        white_mask = cv2.inRange(hsv_image, lower_white, upper_white)

        # 하얀색에 해당하는 마스크를 사용하여 해당 색상만 추출합니다.
        # 새 이미지 생성
        result_image = image.copy()
        result_image[white_mask == 0] = [0, 0, 0]

        # 최종 결과물 저장
        if self.save:
            cv2.imwrite(os.path.join(self.save_folder, self.save_name + '_extract_Norm.jpg'), result_image)

        self.image = result_image
        return self.image


    def gaussian_blur(self, image=None, kernel_size=(5, 5), sigma_x=0, save=False):
        """
        이미지에 가우시안 블러를 적용하는 함수
        :param image: 원본 이미지
        :param kernel_size: 커널 크기, (너비, 높이) 형태의 튜플. 커널 크기가 커질수록 더 많이 흐려짐.
        :param sigma_x: 가우시안 커널의 X 방향 표준편차. 0이면 커널 크기로부터 자동 계산됨.
        :return: 가우시안 블러가 적용된 이미지
        """
        if image is None:
            image = self.image

        gaussian_image = cv2.GaussianBlur(image, kernel_size, sigma_x)

        if self.save:
            cv2.imwrite(os.path.join(self.save_folder, self.save_name+ '_gaussian.jpg'), gaussian_image)

        self.image = gaussian_image
        return self.image


    def median_blur(self, image=None, kernel_size=5, save=False):
        """
        지정된 이미지에 미디언 블러를 적용하는 함수입니다.
        :param image: 처리할 이미지의 파일 경로입니다.
        :param kernel_size: 미디언 블러를 적용할 때 사용할 커널 크기입니다. 기본값은 5입니다.
        :param show_result: 처리된 이미지를 보여줄지 여부입니다. 기본값은 True입니다.
        """
        if image is None:
            image = self.image

        # 미디언 블러를 적용합니다.
        median_image = cv2.medianBlur(image, kernel_size)

        if self.save:
            cv2.imwrite(os.path.join(self.save_folder, self.save_name + '_median.jpg'), median_image)

        self.image = median_image
        return self.image


    def binarize_image(self, image=None, save=False):
        if image is None:
            image = self.image

        # 이미지를 그레이스케일로 로드
        image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

        # 이진화 수행
        _, otsu_thresholded = cv2.threshold(image, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

        if self.save:
            cv2.imwrite(os.path.join(self.save_folder, self.save_name + '_binary.jpg'), otsu_thresholded)

        self.image = otsu_thresholded
        return self.image


    # RGB to CMYK 변환 함수 -> 폐기 ....가능성 다분
    def rgb_to_cmyk(self, image):

        # 이미지를 0~1 사이로 정규화
        rgb_image = image.astype(np.float32) / 255.0

        r = rgb_image[:,:,2]
        g = rgb_image[:,:,1]
        b = rgb_image[:,:,0]

        c = 1 - r
        m = 1 - g
        y = 1 - b

        k = np.minimum(c, np.minimum(m, y))

        c = (c - k) / (1 - k + 1e-10)  # 0으로 나누는 오류를 피하기 위해 작은 값 추가
        m = (m - k) / (1 - k + 1e-10)
        y = (y - k) / (1 - k + 1e-10)

        # K 값은 그대로 사용
        k = k

        # CMYK 이미지 생성 (0~100% 범위로 변환)
        cmyk_image = np.stack([c, m, y, k], axis=-1) * 100
        cmyk_image = cmyk_image.astype(np.uint8)
        return cmyk_image


    def cmyk_transfer(self, image=None, save=False):
        if image is None:
            image = self.image

        # 오리지널 이미지
        ori_image = image

        # RGB 이미지를 CMYK로 변환
        cmyk_image = self.rgb_to_cmyk(ori_image)

        # CMYK 색상 범위 설정 (0~100%)
                                    # [C, M, Y, K]
        # upper_bound_cmyk = np.array([100, 100, 100, 100])  # 상한값
        # lower_bound_cmyk = np.array([0, 0, 0, 0])  # 하한값
        upper_bound_cmyk = np.array([0, 30, 100, 10])  # 상한값
        lower_bound_cmyk = np.array([0, 0, 60, 0])  # 하한값


        # 특정 색상 범위에 해당하는 부분을 이진화하여 마스크 생성
        mask_cmyk = cv2.inRange(cmyk_image, lower_bound_cmyk, upper_bound_cmyk)

        # 특정 색상 부분만 추출
        result_cmyk = cv2.bitwise_and(ori_image, ori_image, mask=mask_cmyk)

        if self.save:
            cv2.imwrite(os.path.join(self.save_folder, self.save_name + '_cymk.jpg'), result_cmyk)

        self.image = result_cmyk
        return self.image


    def process_image(self, operations):
        """
        전처리 테스트용 함수.
        operations: 실행하고자 하는 작업들의 리스트. 예: ['apply_mask', 'resize_image', 'extract_yellow', 'gaussian_blur']
        """
        image = self.image
        for operation in operations:
            if hasattr(self, operation):
                method = getattr(self, operation)
                image = method(image)
            else:
                print(f"{operation} 메서드는 존재하지 않습니다.")

        return image

# %% [markdown]
# # 테스트 코드

# %% [markdown]
# ## process-class

# %%
### 사용 예시 ###
"""
# 비디오 클래스와 비슷함. 그리고 blur들에 경우 커널 사이즈를 정할 수 있습니다.
param kernel_size: 커널 크기, (너비, 높이) 형태의 튜플. 커널 크기가 커질수록 더 많이 흐려짐. -> 변경을 원할시 method 에서 직접 변경해주셔야 합니다.
색 추출을 위한 픽셀값은 상한값 하한값들이 클래스내에 이미 추천해놨습니다. 2가지 경우를 바꾸면서 원하시는것을 사용해주세요.

image_data = cv2.imread("/content/drive/MyDrive/Colab Notebooks/OCR-project/dataset/1/striker_valtan_gate_02(jpg)/frame10_12954.jpg")   # 이미지에 대해 전처리만 원하시면 cv2.imread("경로")를 해주세요.
save_folder = "/content/drive/MyDrive/Colab Notebooks/OCR-project/dataset/test"                                                         # 저장 경로
save_name = "test_12954"                                                                                                                # 유니크 이름

preprocess_obj = preprocess(image_path, save_folder, save_name, save=False, size_type=1)
processed_image = preprocess_obj.process_image(['apply_mask', 'resize_image', 'extract_yellow', 'gaussian_blur'])
"""
# Out:
# '\n# 비디오 클래스와 비슷함. 그리고 blur들에 경우 커널 사이즈를 정할 수 있습니다.\nparam kernel_size: 커널 크기, (너비, 높이) 형태의 튜플. 커널 크기가 커질수록 더 많이 흐려짐. -> 변경을 원할시 method 에서 직접 변경해주셔야 합니다.\n색 추출을 위한 픽셀값은 상한값 하한값들이 클래스내에 이미 추천해놨습니다. 2가지 경우를 바꾸면서 원하시는것을 사용해주세요.\n\nimage_data = cv2.imread("/content/drive/MyDrive/Colab Notebooks/OCR-project/dataset/1/striker_valtan_gate_02(jpg)/frame10_12954.jpg")   # 이미지에 대해 전처리만 원하시면 cv2.imread("경로")를 해주세요.\nsave_folder = "/content/drive/MyDrive/Colab Notebooks/OCR-project/dataset/test"                                                         # 저장 경로\nsave_name = "test_12954"                                                                                                                # 유니크 이름\n\npreprocess_obj = preprocess(image_path, save_folder, save_name, save=False, size_type=1)\nprocessed_image = preprocess_obj.process_image([\'apply_mask\', \'resize_image\', \'extract_yellow\', \'gaussian_blur\'])\n'

# %%
# 반환된 이미지 배열을 사진으로 보여주기
cv2.imshow("Processed Image", processed_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ## video-class 테스트

# %%
### 사용 예시 ###
"""
video_path = '/content/drive/MyDrive/Colab Notebooks/OCR-project/dataset/Lost Ark 2min.mp4' # 사용경로
save_folder = '/content/drive/MyDrive/Colab Notebooks/OCR-project/dataset/test'             # 저장경로
save_name_prefix = 'frame'                                                                  # unique 한 이름 보통 (닉네임 또는 직업명)
fps = 12                                                                                    # 원하는 프레임

video_preprocessor = VideoPreprocessor(video_path, save_folder, save_name_prefix, fps=fps, size_type=1)     # quality 파라미터 도 있다. => 700 ~ 850, type 2는 비율
                                                                                                            # 만약 전처리 되는 사진들까지 저장하고 싶다면, save=True

video_preprocessor.preprocess_video(['apply_mask', 'resize_image', 'extract_yellow', 'gaussian_blur'])      # 원하는 전처리 메소드를 리스트안에 넣어서 시작
"""
## 아웃풋 -> blade_56.jpg

# %%
video_path = r'D:\project&competition\sol\dataset\Lost Ark 30s.mp4' # 사용경로
save_folder = r"D:\project&competition\sol\dataset\test\1\white" # 저장경로
save_name_prefix = 'arcana'
fps = 12

video_preprocessor = VideoPreprocessor(video_path, save_folder, save_name_prefix, fps=fps, size_type=1, quality=850, save=False)
video_preprocessor.preprocess_video(operations=['apply_mask', 'resize_image', 'extract_white','binarize_image'])

# %%
cap = cv2.VideoCapture(r'D:\project&competition\sol\dataset\striker_valtan_02_gate_02.mp4')
fps = 5

# 설정한 FPS에 맞춰 간격을 계산
frame_interval = round(cap.get(cv2.CAP_PROP_FPS) / fps)  # fps = 내가 원하는 output의 fps 10 fps = 60/10 => 1초에 10장이 나오는 6fps으로 나눈것.
total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
current_frame = 0

print(frame_interval)
print(total_frames)
# Out:
# 12
# 28986

# %%
video_path = r'D:\project&competition\sol\dataset\striker_valtan_02_gate_02.mp4' # 사용경로
save_folder1 = r"D:\project&competition\sol\dataset\test\2\yellow" # 저장경로
save_folder2 = r"D:\project&competition\sol\dataset\test\2\white" # 저장경로
save_name_prefix = 'striker'
fps = 5

video_preprocessor = VideoPreprocessor(video_path, save_folder1, save_name_prefix, fps=fps, size_type=1, quality=850, save=False)
video_preprocessor.preprocess_video(operations=['apply_mask', 'resize_image', 'extract_yellow','binarize_image', 'gaussian_blur'])

video_preprocessor = VideoPreprocessor(video_path, save_folder2, save_name_prefix, fps=fps, size_type=1, quality=850, save=False)
video_preprocessor.preprocess_video(operations=['apply_mask', 'resize_image', 'extract_white','binarize_image', 'gaussian_blur'])
# Out:
# D:\project&competition\sol\dataset\test\2\yellow\striker_0.jpg 저장 완료 (0/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_12.jpg 저장 완료 (12/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_24.jpg 저장 완료 (24/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_36.jpg 저장 완료 (36/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_48.jpg 저장 완료 (48/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_60.jpg 저장 완료 (60/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_72.jpg 저장 완료 (72/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_84.jpg 저장 완료 (84/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_96.jpg 저장 완료 (96/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_108.jpg 저장 완료 (108/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_120.jpg 저장 완료 (120/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_132.jpg 저장 완료 (132/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_144.jpg 저장 완료 (144/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_156.jpg 저장 완료 (156/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_168.jpg 저장 완료 (168/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_180.jpg 저장 완료 (180/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_192.jpg 저장 완료 (192/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_204.jpg 저장 완료 (204/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_216.jpg 저장 완료 (216/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_228.jpg 저장 완료 (228/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_240.jpg 저장 완료 (240/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_252.jpg 저장 완료 (252/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_264.jpg 저장 완료 (264/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_276.jpg 저장 완료 (276/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_288.jpg 저장 완료 (288/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_300.jpg 저장 완료 (300/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_312.jpg 저장 완료 (312/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_324.jpg 저장 완료 (324/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_336.jpg 저장 완료 (336/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_348.jpg 저장 완료 (348/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_360.jpg 저장 완료 (360/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_372.jpg 저장 완료 (372/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_384.jpg 저장 완료 (384/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_396.jpg 저장 완료 (396/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_408.jpg 저장 완료 (408/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_420.jpg 저장 완료 (420/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_432.jpg 저장 완료 (432/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_444.jpg 저장 완료 (444/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_456.jpg 저장 완료 (456/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_468.jpg 저장 완료 (468/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_480.jpg 저장 완료 (480/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_492.jpg 저장 완료 (492/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_504.jpg 저장 완료 (504/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_516.jpg 저장 완료 (516/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_528.jpg 저장 완료 (528/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_540.jpg 저장 완료 (540/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_552.jpg 저장 완료 (552/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_564.jpg 저장 완료 (564/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_576.jpg 저장 완료 (576/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_588.jpg 저장 완료 (588/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_600.jpg 저장 완료 (600/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_612.jpg 저장 완료 (612/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_624.jpg 저장 완료 (624/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_636.jpg 저장 완료 (636/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_648.jpg 저장 완료 (648/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_660.jpg 저장 완료 (660/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_672.jpg 저장 완료 (672/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_684.jpg 저장 완료 (684/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_696.jpg 저장 완료 (696/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_708.jpg 저장 완료 (708/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_720.jpg 저장 완료 (720/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_732.jpg 저장 완료 (732/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_744.jpg 저장 완료 (744/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_756.jpg 저장 완료 (756/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_768.jpg 저장 완료 (768/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_780.jpg 저장 완료 (780/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_792.jpg 저장 완료 (792/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_804.jpg 저장 완료 (804/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_816.jpg 저장 완료 (816/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_828.jpg 저장 완료 (828/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_840.jpg 저장 완료 (840/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_852.jpg 저장 완료 (852/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_864.jpg 저장 완료 (864/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_876.jpg 저장 완료 (876/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_888.jpg 저장 완료 (888/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_900.jpg 저장 완료 (900/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_912.jpg 저장 완료 (912/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_924.jpg 저장 완료 (924/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_936.jpg 저장 완료 (936/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_948.jpg 저장 완료 (948/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_960.jpg 저장 완료 (960/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_972.jpg 저장 완료 (972/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_984.jpg 저장 완료 (984/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_996.jpg 저장 완료 (996/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_1008.jpg 저장 완료 (1008/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_1020.jpg 저장 완료 (1020/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_1032.jpg 저장 완료 (1032/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_1044.jpg 저장 완료 (1044/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_1056.jpg 저장 완료 (1056/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_1068.jpg 저장 완료 (1068/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_1080.jpg 저장 완료 (1080/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_1092.jpg 저장 완료 (1092/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_1104.jpg 저장 완료 (1104/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_1116.jpg 저장 완료 (1116/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_1128.jpg 저장 완료 (1128/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_1140.jpg 저장 완료 (1140/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_1152.jpg 저장 완료 (1152/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_1164.jpg 저장 완료 (1164/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_1176.jpg 저장 완료 (1176/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_1188.jpg 저장 완료 (1188/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_1200.jpg 저장 완료 (1200/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_1212.jpg 저장 완료 (1212/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_1224.jpg 저장 완료 (1224/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_1236.jpg 저장 완료 (1236/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_1248.jpg 저장 완료 (1248/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_1260.jpg 저장 완료 (1260/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_1272.jpg 저장 완료 (1272/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_1284.jpg 저장 완료 (1284/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_1296.jpg 저장 완료 (1296/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_1308.jpg 저장 완료 (1308/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_1320.jpg 저장 완료 (1320/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_1332.jpg 저장 완료 (1332/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_1344.jpg 저장 완료 (1344/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_1356.jpg 저장 완료 (1356/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_1368.jpg 저장 완료 (1368/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_1380.jpg 저장 완료 (1380/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_1392.jpg 저장 완료 (1392/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_1404.jpg 저장 완료 (1404/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_1416.jpg 저장 완료 (1416/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_1428.jpg 저장 완료 (1428/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_1440.jpg 저장 완료 (1440/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_1452.jpg 저장 완료 (1452/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_1464.jpg 저장 완료 (1464/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_1476.jpg 저장 완료 (1476/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_1488.jpg 저장 완료 (1488/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_1500.jpg 저장 완료 (1500/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_1512.jpg 저장 완료 (1512/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_1524.jpg 저장 완료 (1524/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_1536.jpg 저장 완료 (1536/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_1548.jpg 저장 완료 (1548/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_1560.jpg 저장 완료 (1560/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_1572.jpg 저장 완료 (1572/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_1584.jpg 저장 완료 (1584/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_1596.jpg 저장 완료 (1596/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_1608.jpg 저장 완료 (1608/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_1620.jpg 저장 완료 (1620/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_1632.jpg 저장 완료 (1632/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_1644.jpg 저장 완료 (1644/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_1656.jpg 저장 완료 (1656/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_1668.jpg 저장 완료 (1668/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_1680.jpg 저장 완료 (1680/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_1692.jpg 저장 완료 (1692/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_1704.jpg 저장 완료 (1704/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_1716.jpg 저장 완료 (1716/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_1728.jpg 저장 완료 (1728/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_1740.jpg 저장 완료 (1740/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_1752.jpg 저장 완료 (1752/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_1764.jpg 저장 완료 (1764/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_1776.jpg 저장 완료 (1776/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_1788.jpg 저장 완료 (1788/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_1800.jpg 저장 완료 (1800/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_1812.jpg 저장 완료 (1812/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_1824.jpg 저장 완료 (1824/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_1836.jpg 저장 완료 (1836/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_1848.jpg 저장 완료 (1848/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_1860.jpg 저장 완료 (1860/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_1872.jpg 저장 완료 (1872/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_1884.jpg 저장 완료 (1884/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_1896.jpg 저장 완료 (1896/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_1908.jpg 저장 완료 (1908/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_1920.jpg 저장 완료 (1920/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_1932.jpg 저장 완료 (1932/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_1944.jpg 저장 완료 (1944/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_1956.jpg 저장 완료 (1956/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_1968.jpg 저장 완료 (1968/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_1980.jpg 저장 완료 (1980/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_1992.jpg 저장 완료 (1992/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_2004.jpg 저장 완료 (2004/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_2016.jpg 저장 완료 (2016/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_2028.jpg 저장 완료 (2028/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_2040.jpg 저장 완료 (2040/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_2052.jpg 저장 완료 (2052/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_2064.jpg 저장 완료 (2064/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_2076.jpg 저장 완료 (2076/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_2088.jpg 저장 완료 (2088/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_2100.jpg 저장 완료 (2100/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_2112.jpg 저장 완료 (2112/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_2124.jpg 저장 완료 (2124/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_2136.jpg 저장 완료 (2136/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_2148.jpg 저장 완료 (2148/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_2160.jpg 저장 완료 (2160/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_2172.jpg 저장 완료 (2172/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_2184.jpg 저장 완료 (2184/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_2196.jpg 저장 완료 (2196/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_2208.jpg 저장 완료 (2208/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_2220.jpg 저장 완료 (2220/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_2232.jpg 저장 완료 (2232/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_2244.jpg 저장 완료 (2244/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_2256.jpg 저장 완료 (2256/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_2268.jpg 저장 완료 (2268/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_2280.jpg 저장 완료 (2280/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_2292.jpg 저장 완료 (2292/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_2304.jpg 저장 완료 (2304/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_2316.jpg 저장 완료 (2316/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_2328.jpg 저장 완료 (2328/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_2340.jpg 저장 완료 (2340/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_2352.jpg 저장 완료 (2352/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_2364.jpg 저장 완료 (2364/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_2376.jpg 저장 완료 (2376/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_2388.jpg 저장 완료 (2388/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_2400.jpg 저장 완료 (2400/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_2412.jpg 저장 완료 (2412/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_2424.jpg 저장 완료 (2424/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_2436.jpg 저장 완료 (2436/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_2448.jpg 저장 완료 (2448/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_2460.jpg 저장 완료 (2460/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_2472.jpg 저장 완료 (2472/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_2484.jpg 저장 완료 (2484/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_2496.jpg 저장 완료 (2496/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_2508.jpg 저장 완료 (2508/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_2520.jpg 저장 완료 (2520/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_2532.jpg 저장 완료 (2532/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_2544.jpg 저장 완료 (2544/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_2556.jpg 저장 완료 (2556/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_2568.jpg 저장 완료 (2568/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_2580.jpg 저장 완료 (2580/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_2592.jpg 저장 완료 (2592/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_2604.jpg 저장 완료 (2604/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_2616.jpg 저장 완료 (2616/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_2628.jpg 저장 완료 (2628/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_2640.jpg 저장 완료 (2640/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_2652.jpg 저장 완료 (2652/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_2664.jpg 저장 완료 (2664/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_2676.jpg 저장 완료 (2676/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_2688.jpg 저장 완료 (2688/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_2700.jpg 저장 완료 (2700/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_2712.jpg 저장 완료 (2712/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_2724.jpg 저장 완료 (2724/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_2736.jpg 저장 완료 (2736/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_2748.jpg 저장 완료 (2748/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_2760.jpg 저장 완료 (2760/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_2772.jpg 저장 완료 (2772/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_2784.jpg 저장 완료 (2784/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_2796.jpg 저장 완료 (2796/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_2808.jpg 저장 완료 (2808/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_2820.jpg 저장 완료 (2820/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_2832.jpg 저장 완료 (2832/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_2844.jpg 저장 완료 (2844/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_2856.jpg 저장 완료 (2856/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_2868.jpg 저장 완료 (2868/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_2880.jpg 저장 완료 (2880/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_2892.jpg 저장 완료 (2892/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_2904.jpg 저장 완료 (2904/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_2916.jpg 저장 완료 (2916/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_2928.jpg 저장 완료 (2928/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_2940.jpg 저장 완료 (2940/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_2952.jpg 저장 완료 (2952/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_2964.jpg 저장 완료 (2964/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_2976.jpg 저장 완료 (2976/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_2988.jpg 저장 완료 (2988/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_3000.jpg 저장 완료 (3000/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_3012.jpg 저장 완료 (3012/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_3024.jpg 저장 완료 (3024/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_3036.jpg 저장 완료 (3036/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_3048.jpg 저장 완료 (3048/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_3060.jpg 저장 완료 (3060/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_3072.jpg 저장 완료 (3072/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_3084.jpg 저장 완료 (3084/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_3096.jpg 저장 완료 (3096/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_3108.jpg 저장 완료 (3108/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_3120.jpg 저장 완료 (3120/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_3132.jpg 저장 완료 (3132/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_3144.jpg 저장 완료 (3144/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_3156.jpg 저장 완료 (3156/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_3168.jpg 저장 완료 (3168/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_3180.jpg 저장 완료 (3180/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_3192.jpg 저장 완료 (3192/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_3204.jpg 저장 완료 (3204/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_3216.jpg 저장 완료 (3216/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_3228.jpg 저장 완료 (3228/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_3240.jpg 저장 완료 (3240/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_3252.jpg 저장 완료 (3252/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_3264.jpg 저장 완료 (3264/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_3276.jpg 저장 완료 (3276/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_3288.jpg 저장 완료 (3288/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_3300.jpg 저장 완료 (3300/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_3312.jpg 저장 완료 (3312/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_3324.jpg 저장 완료 (3324/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_3336.jpg 저장 완료 (3336/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_3348.jpg 저장 완료 (3348/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_3360.jpg 저장 완료 (3360/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_3372.jpg 저장 완료 (3372/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_3384.jpg 저장 완료 (3384/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_3396.jpg 저장 완료 (3396/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_3408.jpg 저장 완료 (3408/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_3420.jpg 저장 완료 (3420/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_3432.jpg 저장 완료 (3432/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_3444.jpg 저장 완료 (3444/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_3456.jpg 저장 완료 (3456/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_3468.jpg 저장 완료 (3468/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_3480.jpg 저장 완료 (3480/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_3492.jpg 저장 완료 (3492/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_3504.jpg 저장 완료 (3504/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_3516.jpg 저장 완료 (3516/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_3528.jpg 저장 완료 (3528/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_3540.jpg 저장 완료 (3540/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_3552.jpg 저장 완료 (3552/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_3564.jpg 저장 완료 (3564/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_3576.jpg 저장 완료 (3576/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_3588.jpg 저장 완료 (3588/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_3600.jpg 저장 완료 (3600/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_3612.jpg 저장 완료 (3612/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_3624.jpg 저장 완료 (3624/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_3636.jpg 저장 완료 (3636/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_3648.jpg 저장 완료 (3648/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_3660.jpg 저장 완료 (3660/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_3672.jpg 저장 완료 (3672/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_3684.jpg 저장 완료 (3684/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_3696.jpg 저장 완료 (3696/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_3708.jpg 저장 완료 (3708/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_3720.jpg 저장 완료 (3720/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_3732.jpg 저장 완료 (3732/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_3744.jpg 저장 완료 (3744/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_3756.jpg 저장 완료 (3756/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_3768.jpg 저장 완료 (3768/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_3780.jpg 저장 완료 (3780/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_3792.jpg 저장 완료 (3792/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_3804.jpg 저장 완료 (3804/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_3816.jpg 저장 완료 (3816/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_3828.jpg 저장 완료 (3828/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_3840.jpg 저장 완료 (3840/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_3852.jpg 저장 완료 (3852/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_3864.jpg 저장 완료 (3864/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_3876.jpg 저장 완료 (3876/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_3888.jpg 저장 완료 (3888/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_3900.jpg 저장 완료 (3900/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_3912.jpg 저장 완료 (3912/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_3924.jpg 저장 완료 (3924/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_3936.jpg 저장 완료 (3936/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_3948.jpg 저장 완료 (3948/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_3960.jpg 저장 완료 (3960/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_3972.jpg 저장 완료 (3972/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_3984.jpg 저장 완료 (3984/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_3996.jpg 저장 완료 (3996/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_4008.jpg 저장 완료 (4008/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_4020.jpg 저장 완료 (4020/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_4032.jpg 저장 완료 (4032/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_4044.jpg 저장 완료 (4044/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_4056.jpg 저장 완료 (4056/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_4068.jpg 저장 완료 (4068/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_4080.jpg 저장 완료 (4080/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_4092.jpg 저장 완료 (4092/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_4104.jpg 저장 완료 (4104/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_4116.jpg 저장 완료 (4116/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_4128.jpg 저장 완료 (4128/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_4140.jpg 저장 완료 (4140/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_4152.jpg 저장 완료 (4152/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_4164.jpg 저장 완료 (4164/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_4176.jpg 저장 완료 (4176/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_4188.jpg 저장 완료 (4188/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_4200.jpg 저장 완료 (4200/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_4212.jpg 저장 완료 (4212/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_4224.jpg 저장 완료 (4224/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_4236.jpg 저장 완료 (4236/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_4248.jpg 저장 완료 (4248/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_4260.jpg 저장 완료 (4260/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_4272.jpg 저장 완료 (4272/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_4284.jpg 저장 완료 (4284/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_4296.jpg 저장 완료 (4296/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_4308.jpg 저장 완료 (4308/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_4320.jpg 저장 완료 (4320/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_4332.jpg 저장 완료 (4332/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_4344.jpg 저장 완료 (4344/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_4356.jpg 저장 완료 (4356/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_4368.jpg 저장 완료 (4368/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_4380.jpg 저장 완료 (4380/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_4392.jpg 저장 완료 (4392/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_4404.jpg 저장 완료 (4404/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_4416.jpg 저장 완료 (4416/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_4428.jpg 저장 완료 (4428/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_4440.jpg 저장 완료 (4440/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_4452.jpg 저장 완료 (4452/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_4464.jpg 저장 완료 (4464/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_4476.jpg 저장 완료 (4476/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_4488.jpg 저장 완료 (4488/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_4500.jpg 저장 완료 (4500/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_4512.jpg 저장 완료 (4512/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_4524.jpg 저장 완료 (4524/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_4536.jpg 저장 완료 (4536/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_4548.jpg 저장 완료 (4548/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_4560.jpg 저장 완료 (4560/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_4572.jpg 저장 완료 (4572/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_4584.jpg 저장 완료 (4584/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_4596.jpg 저장 완료 (4596/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_4608.jpg 저장 완료 (4608/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_4620.jpg 저장 완료 (4620/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_4632.jpg 저장 완료 (4632/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_4644.jpg 저장 완료 (4644/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_4656.jpg 저장 완료 (4656/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_4668.jpg 저장 완료 (4668/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_4680.jpg 저장 완료 (4680/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_4692.jpg 저장 완료 (4692/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_4704.jpg 저장 완료 (4704/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_4716.jpg 저장 완료 (4716/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_4728.jpg 저장 완료 (4728/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_4740.jpg 저장 완료 (4740/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_4752.jpg 저장 완료 (4752/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_4764.jpg 저장 완료 (4764/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_4776.jpg 저장 완료 (4776/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_4788.jpg 저장 완료 (4788/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_4800.jpg 저장 완료 (4800/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_4812.jpg 저장 완료 (4812/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_4824.jpg 저장 완료 (4824/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_4836.jpg 저장 완료 (4836/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_4848.jpg 저장 완료 (4848/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_4860.jpg 저장 완료 (4860/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_4872.jpg 저장 완료 (4872/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_4884.jpg 저장 완료 (4884/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_4896.jpg 저장 완료 (4896/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_4908.jpg 저장 완료 (4908/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_4920.jpg 저장 완료 (4920/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_4932.jpg 저장 완료 (4932/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_4944.jpg 저장 완료 (4944/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_4956.jpg 저장 완료 (4956/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_4968.jpg 저장 완료 (4968/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_4980.jpg 저장 완료 (4980/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_4992.jpg 저장 완료 (4992/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_5004.jpg 저장 완료 (5004/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_5016.jpg 저장 완료 (5016/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_5028.jpg 저장 완료 (5028/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_5040.jpg 저장 완료 (5040/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_5052.jpg 저장 완료 (5052/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_5064.jpg 저장 완료 (5064/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_5076.jpg 저장 완료 (5076/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_5088.jpg 저장 완료 (5088/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_5100.jpg 저장 완료 (5100/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_5112.jpg 저장 완료 (5112/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_5124.jpg 저장 완료 (5124/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_5136.jpg 저장 완료 (5136/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_5148.jpg 저장 완료 (5148/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_5160.jpg 저장 완료 (5160/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_5172.jpg 저장 완료 (5172/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_5184.jpg 저장 완료 (5184/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_5196.jpg 저장 완료 (5196/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_5208.jpg 저장 완료 (5208/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_5220.jpg 저장 완료 (5220/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_5232.jpg 저장 완료 (5232/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_5244.jpg 저장 완료 (5244/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_5256.jpg 저장 완료 (5256/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_5268.jpg 저장 완료 (5268/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_5280.jpg 저장 완료 (5280/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_5292.jpg 저장 완료 (5292/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_5304.jpg 저장 완료 (5304/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_5316.jpg 저장 완료 (5316/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_5328.jpg 저장 완료 (5328/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_5340.jpg 저장 완료 (5340/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_5352.jpg 저장 완료 (5352/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_5364.jpg 저장 완료 (5364/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_5376.jpg 저장 완료 (5376/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_5388.jpg 저장 완료 (5388/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_5400.jpg 저장 완료 (5400/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_5412.jpg 저장 완료 (5412/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_5424.jpg 저장 완료 (5424/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_5436.jpg 저장 완료 (5436/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_5448.jpg 저장 완료 (5448/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_5460.jpg 저장 완료 (5460/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_5472.jpg 저장 완료 (5472/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_5484.jpg 저장 완료 (5484/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_5496.jpg 저장 완료 (5496/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_5508.jpg 저장 완료 (5508/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_5520.jpg 저장 완료 (5520/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_5532.jpg 저장 완료 (5532/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_5544.jpg 저장 완료 (5544/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_5556.jpg 저장 완료 (5556/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_5568.jpg 저장 완료 (5568/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_5580.jpg 저장 완료 (5580/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_5592.jpg 저장 완료 (5592/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_5604.jpg 저장 완료 (5604/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_5616.jpg 저장 완료 (5616/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_5628.jpg 저장 완료 (5628/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_5640.jpg 저장 완료 (5640/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_5652.jpg 저장 완료 (5652/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_5664.jpg 저장 완료 (5664/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_5676.jpg 저장 완료 (5676/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_5688.jpg 저장 완료 (5688/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_5700.jpg 저장 완료 (5700/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_5712.jpg 저장 완료 (5712/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_5724.jpg 저장 완료 (5724/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_5736.jpg 저장 완료 (5736/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_5748.jpg 저장 완료 (5748/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_5760.jpg 저장 완료 (5760/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_5772.jpg 저장 완료 (5772/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_5784.jpg 저장 완료 (5784/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_5796.jpg 저장 완료 (5796/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_5808.jpg 저장 완료 (5808/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_5820.jpg 저장 완료 (5820/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_5832.jpg 저장 완료 (5832/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_5844.jpg 저장 완료 (5844/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_5856.jpg 저장 완료 (5856/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_5868.jpg 저장 완료 (5868/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_5880.jpg 저장 완료 (5880/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_5892.jpg 저장 완료 (5892/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_5904.jpg 저장 완료 (5904/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_5916.jpg 저장 완료 (5916/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_5928.jpg 저장 완료 (5928/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_5940.jpg 저장 완료 (5940/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_5952.jpg 저장 완료 (5952/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_5964.jpg 저장 완료 (5964/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_5976.jpg 저장 완료 (5976/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_5988.jpg 저장 완료 (5988/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_6000.jpg 저장 완료 (6000/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_6012.jpg 저장 완료 (6012/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_6024.jpg 저장 완료 (6024/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_6036.jpg 저장 완료 (6036/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_6048.jpg 저장 완료 (6048/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_6060.jpg 저장 완료 (6060/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_6072.jpg 저장 완료 (6072/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_6084.jpg 저장 완료 (6084/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_6096.jpg 저장 완료 (6096/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_6108.jpg 저장 완료 (6108/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_6120.jpg 저장 완료 (6120/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_6132.jpg 저장 완료 (6132/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_6144.jpg 저장 완료 (6144/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_6156.jpg 저장 완료 (6156/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_6168.jpg 저장 완료 (6168/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_6180.jpg 저장 완료 (6180/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_6192.jpg 저장 완료 (6192/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_6204.jpg 저장 완료 (6204/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_6216.jpg 저장 완료 (6216/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_6228.jpg 저장 완료 (6228/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_6240.jpg 저장 완료 (6240/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_6252.jpg 저장 완료 (6252/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_6264.jpg 저장 완료 (6264/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_6276.jpg 저장 완료 (6276/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_6288.jpg 저장 완료 (6288/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_6300.jpg 저장 완료 (6300/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_6312.jpg 저장 완료 (6312/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_6324.jpg 저장 완료 (6324/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_6336.jpg 저장 완료 (6336/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_6348.jpg 저장 완료 (6348/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_6360.jpg 저장 완료 (6360/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_6372.jpg 저장 완료 (6372/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_6384.jpg 저장 완료 (6384/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_6396.jpg 저장 완료 (6396/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_6408.jpg 저장 완료 (6408/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_6420.jpg 저장 완료 (6420/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_6432.jpg 저장 완료 (6432/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_6444.jpg 저장 완료 (6444/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_6456.jpg 저장 완료 (6456/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_6468.jpg 저장 완료 (6468/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_6480.jpg 저장 완료 (6480/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_6492.jpg 저장 완료 (6492/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_6504.jpg 저장 완료 (6504/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_6516.jpg 저장 완료 (6516/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_6528.jpg 저장 완료 (6528/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_6540.jpg 저장 완료 (6540/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_6552.jpg 저장 완료 (6552/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_6564.jpg 저장 완료 (6564/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_6576.jpg 저장 완료 (6576/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_6588.jpg 저장 완료 (6588/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_6600.jpg 저장 완료 (6600/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_6612.jpg 저장 완료 (6612/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_6624.jpg 저장 완료 (6624/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_6636.jpg 저장 완료 (6636/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_6648.jpg 저장 완료 (6648/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_6660.jpg 저장 완료 (6660/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_6672.jpg 저장 완료 (6672/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_6684.jpg 저장 완료 (6684/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_6696.jpg 저장 완료 (6696/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_6708.jpg 저장 완료 (6708/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_6720.jpg 저장 완료 (6720/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_6732.jpg 저장 완료 (6732/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_6744.jpg 저장 완료 (6744/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_6756.jpg 저장 완료 (6756/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_6768.jpg 저장 완료 (6768/28986)
# D:\project&competition\sol\dataset\test\2\yellow\striker_6780.jpg 저장 완료 (6780/28986)
# ...
# D:\project&competition\sol\dataset\test\2\white\striker_26772.jpg 저장 완료 (26772/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_26784.jpg 저장 완료 (26784/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_26796.jpg 저장 완료 (26796/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_26808.jpg 저장 완료 (26808/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_26820.jpg 저장 완료 (26820/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_26832.jpg 저장 완료 (26832/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_26844.jpg 저장 완료 (26844/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_26856.jpg 저장 완료 (26856/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_26868.jpg 저장 완료 (26868/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_26880.jpg 저장 완료 (26880/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_26892.jpg 저장 완료 (26892/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_26904.jpg 저장 완료 (26904/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_26916.jpg 저장 완료 (26916/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_26928.jpg 저장 완료 (26928/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_26940.jpg 저장 완료 (26940/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_26952.jpg 저장 완료 (26952/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_26964.jpg 저장 완료 (26964/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_26976.jpg 저장 완료 (26976/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_26988.jpg 저장 완료 (26988/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_27000.jpg 저장 완료 (27000/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_27012.jpg 저장 완료 (27012/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_27024.jpg 저장 완료 (27024/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_27036.jpg 저장 완료 (27036/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_27048.jpg 저장 완료 (27048/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_27060.jpg 저장 완료 (27060/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_27072.jpg 저장 완료 (27072/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_27084.jpg 저장 완료 (27084/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_27096.jpg 저장 완료 (27096/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_27108.jpg 저장 완료 (27108/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_27120.jpg 저장 완료 (27120/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_27132.jpg 저장 완료 (27132/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_27144.jpg 저장 완료 (27144/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_27156.jpg 저장 완료 (27156/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_27168.jpg 저장 완료 (27168/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_27180.jpg 저장 완료 (27180/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_27192.jpg 저장 완료 (27192/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_27204.jpg 저장 완료 (27204/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_27216.jpg 저장 완료 (27216/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_27228.jpg 저장 완료 (27228/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_27240.jpg 저장 완료 (27240/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_27252.jpg 저장 완료 (27252/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_27264.jpg 저장 완료 (27264/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_27276.jpg 저장 완료 (27276/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_27288.jpg 저장 완료 (27288/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_27300.jpg 저장 완료 (27300/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_27312.jpg 저장 완료 (27312/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_27324.jpg 저장 완료 (27324/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_27336.jpg 저장 완료 (27336/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_27348.jpg 저장 완료 (27348/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_27360.jpg 저장 완료 (27360/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_27372.jpg 저장 완료 (27372/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_27384.jpg 저장 완료 (27384/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_27396.jpg 저장 완료 (27396/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_27408.jpg 저장 완료 (27408/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_27420.jpg 저장 완료 (27420/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_27432.jpg 저장 완료 (27432/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_27444.jpg 저장 완료 (27444/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_27456.jpg 저장 완료 (27456/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_27468.jpg 저장 완료 (27468/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_27480.jpg 저장 완료 (27480/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_27492.jpg 저장 완료 (27492/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_27504.jpg 저장 완료 (27504/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_27516.jpg 저장 완료 (27516/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_27528.jpg 저장 완료 (27528/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_27540.jpg 저장 완료 (27540/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_27552.jpg 저장 완료 (27552/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_27564.jpg 저장 완료 (27564/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_27576.jpg 저장 완료 (27576/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_27588.jpg 저장 완료 (27588/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_27600.jpg 저장 완료 (27600/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_27612.jpg 저장 완료 (27612/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_27624.jpg 저장 완료 (27624/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_27636.jpg 저장 완료 (27636/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_27648.jpg 저장 완료 (27648/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_27660.jpg 저장 완료 (27660/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_27672.jpg 저장 완료 (27672/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_27684.jpg 저장 완료 (27684/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_27696.jpg 저장 완료 (27696/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_27708.jpg 저장 완료 (27708/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_27720.jpg 저장 완료 (27720/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_27732.jpg 저장 완료 (27732/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_27744.jpg 저장 완료 (27744/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_27756.jpg 저장 완료 (27756/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_27768.jpg 저장 완료 (27768/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_27780.jpg 저장 완료 (27780/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_27792.jpg 저장 완료 (27792/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_27804.jpg 저장 완료 (27804/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_27816.jpg 저장 완료 (27816/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_27828.jpg 저장 완료 (27828/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_27840.jpg 저장 완료 (27840/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_27852.jpg 저장 완료 (27852/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_27864.jpg 저장 완료 (27864/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_27876.jpg 저장 완료 (27876/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_27888.jpg 저장 완료 (27888/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_27900.jpg 저장 완료 (27900/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_27912.jpg 저장 완료 (27912/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_27924.jpg 저장 완료 (27924/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_27936.jpg 저장 완료 (27936/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_27948.jpg 저장 완료 (27948/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_27960.jpg 저장 완료 (27960/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_27972.jpg 저장 완료 (27972/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_27984.jpg 저장 완료 (27984/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_27996.jpg 저장 완료 (27996/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_28008.jpg 저장 완료 (28008/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_28020.jpg 저장 완료 (28020/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_28032.jpg 저장 완료 (28032/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_28044.jpg 저장 완료 (28044/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_28056.jpg 저장 완료 (28056/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_28068.jpg 저장 완료 (28068/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_28080.jpg 저장 완료 (28080/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_28092.jpg 저장 완료 (28092/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_28104.jpg 저장 완료 (28104/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_28116.jpg 저장 완료 (28116/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_28128.jpg 저장 완료 (28128/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_28140.jpg 저장 완료 (28140/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_28152.jpg 저장 완료 (28152/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_28164.jpg 저장 완료 (28164/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_28176.jpg 저장 완료 (28176/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_28188.jpg 저장 완료 (28188/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_28200.jpg 저장 완료 (28200/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_28212.jpg 저장 완료 (28212/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_28224.jpg 저장 완료 (28224/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_28236.jpg 저장 완료 (28236/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_28248.jpg 저장 완료 (28248/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_28260.jpg 저장 완료 (28260/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_28272.jpg 저장 완료 (28272/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_28284.jpg 저장 완료 (28284/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_28296.jpg 저장 완료 (28296/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_28308.jpg 저장 완료 (28308/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_28320.jpg 저장 완료 (28320/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_28332.jpg 저장 완료 (28332/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_28344.jpg 저장 완료 (28344/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_28356.jpg 저장 완료 (28356/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_28368.jpg 저장 완료 (28368/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_28380.jpg 저장 완료 (28380/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_28392.jpg 저장 완료 (28392/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_28404.jpg 저장 완료 (28404/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_28416.jpg 저장 완료 (28416/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_28428.jpg 저장 완료 (28428/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_28440.jpg 저장 완료 (28440/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_28452.jpg 저장 완료 (28452/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_28464.jpg 저장 완료 (28464/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_28476.jpg 저장 완료 (28476/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_28488.jpg 저장 완료 (28488/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_28500.jpg 저장 완료 (28500/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_28512.jpg 저장 완료 (28512/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_28524.jpg 저장 완료 (28524/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_28536.jpg 저장 완료 (28536/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_28548.jpg 저장 완료 (28548/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_28560.jpg 저장 완료 (28560/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_28572.jpg 저장 완료 (28572/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_28584.jpg 저장 완료 (28584/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_28596.jpg 저장 완료 (28596/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_28608.jpg 저장 완료 (28608/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_28620.jpg 저장 완료 (28620/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_28632.jpg 저장 완료 (28632/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_28644.jpg 저장 완료 (28644/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_28656.jpg 저장 완료 (28656/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_28668.jpg 저장 완료 (28668/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_28680.jpg 저장 완료 (28680/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_28692.jpg 저장 완료 (28692/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_28704.jpg 저장 완료 (28704/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_28716.jpg 저장 완료 (28716/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_28728.jpg 저장 완료 (28728/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_28740.jpg 저장 완료 (28740/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_28752.jpg 저장 완료 (28752/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_28764.jpg 저장 완료 (28764/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_28776.jpg 저장 완료 (28776/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_28788.jpg 저장 완료 (28788/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_28800.jpg 저장 완료 (28800/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_28812.jpg 저장 완료 (28812/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_28824.jpg 저장 완료 (28824/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_28836.jpg 저장 완료 (28836/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_28848.jpg 저장 완료 (28848/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_28860.jpg 저장 완료 (28860/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_28872.jpg 저장 완료 (28872/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_28884.jpg 저장 완료 (28884/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_28896.jpg 저장 완료 (28896/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_28908.jpg 저장 완료 (28908/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_28920.jpg 저장 완료 (28920/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_28932.jpg 저장 완료 (28932/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_28944.jpg 저장 완료 (28944/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_28956.jpg 저장 완료 (28956/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_28968.jpg 저장 완료 (28968/28986)
# D:\project&competition\sol\dataset\test\2\white\striker_28980.jpg 저장 완료 (28980/28986)
# 작업 완료
